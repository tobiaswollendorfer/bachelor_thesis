# %%
import os
import glob
import pandas as pd

# %%
INPUT_DIR = r"comments\preprocessed_vader_incl_meta"
OUTPUT_CSV = r"comments\all_comments_combined.csv"

# Find all CSV files
files = glob.glob(os.path.join(INPUT_DIR, "*.csv"))
print(f"Found {len(files)} CSV files.")
# Out:
# Found 10285 CSV files.

# %%
df_list = []

for idx, f in enumerate(files, start=1):
    if idx % 1000 == 0:
        print(idx)
    try:
        df = pd.read_csv(f, low_memory=False)
        df_list.append(df)
    except Exception as e:
        print(f"Error reading {f}: {e}")

if df_list:
    combined_df = pd.concat(df_list, ignore_index=True)
    combined_df.to_csv(OUTPUT_CSV, index=False, encoding="utf-8")
    print(f"Combined DataFrame shape: {combined_df.shape}")
    print(f"Saved combined file to: {OUTPUT_CSV}")
else:
    print("No dataframes to combine.")
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# Combined DataFrame shape: (635314, 41)
# Saved combined file to: comments\all_comments_combined.csv

# %%
combined_df
# Out:
#                          commentId           authorChannelId  \
# 0       UgzlBcSJtHX9PXkkpU54AaABAg  UCBpZTEYOHZ8LB3v6wuV8h4Q
# 1       Ugx4BcPswi0TUT0XOoh4AaABAg  UC_mUWworB6k2ECgasTyU4Jw
# 2       UgzGjYagodtqT5-0PRl4AaABAg  UCZN8pUIr_W44oy6EiZCt5SQ
# 3       Ugx1irQd66qzIeWAdhF4AaABAg  UCO7zqQJyTPaUXig8w5hu0iw
# 4       UgwiKXxpLTvxdtge5bd4AaABAg  UCeYKHAmtFrxX3aOW_FliThg
# ...                            ...                       ...
# 635309  UgzFGi4YnG2pIyT--ph4AaABAg  UCyNzYnJqU051zzDEhNbAfPg
# 635310  UgxuEoTNo-0Zaf_zabJ4AaABAg  UCMhYMW5csFCNxhjEFFHUNSA
# 635311  Ugx_ur0FsaxXWf5wLJJ4AaABAg  UC-X8KLDGa75PALKDJPVauyQ
# 635312  Ugy9G4GWhVFUzpG5m6l4AaABAg  UCuvUc5Bm6Ek2oyGWoOpy_8A
# 635313  UgzREIEGEqfY-wkL5BB4AaABAg  UCaSmvM7zWEcYNbW3TPWWucA
#
#          authorDisplayName                           authorChannelUrl  \
# 0               @YorHarian          http://www.youtube.com/@YorHarian
# 1       @juniorcaballero25  http://www.youtube.com/@juniorcaballero25
# 2               @lil__boo_          http://www.youtube.com/@lil__boo_
# 3          @erikalbino6405     http://www.youtube.com/@erikalbino6405
# 4       @viniciusrocha1154  http://www.youtube.com/@viniciusrocha1154
# ...                    ...                                        ...
# 635309   @SHIVAMTIWARI-h6e   http://www.youtube.com/@SHIVAMTIWARI-h6e
# 635310         @rajneesh17         http://www.youtube.com/@rajneesh17
# 635311      @Shreyasagumbe      http://www.youtube.com/@Shreyasagumbe
# 635312       @1suhelkhan57       http://www.youtube.com/@1suhelkhan57
# 635313       @plgaming7638       http://www.youtube.com/@plgaming7638
#
#                publishedAt_x             updatedAt  likeCount_x  parentId  \
# 0       2023-03-09T02:15:08Z  2023-03-09T02:15:08Z            0       NaN
# 1       2020-07-09T17:14:11Z  2020-07-09T17:14:11Z            3       NaN
# 2       2020-01-13T03:37:06Z  2020-01-13T03:37:06Z            3       NaN
# 3       2019-07-31T10:33:30Z  2019-07-31T10:34:05Z            3       NaN
# 4       2018-12-26T19:58:00Z  2018-12-26T19:58:00Z            2       NaN
# ...                      ...                   ...          ...       ...
# 635309  2025-03-06T07:59:40Z  2025-03-06T07:59:40Z            3       NaN
# 635310  2025-03-06T07:58:15Z  2025-03-06T07:58:15Z            2       NaN
# 635311  2025-03-06T07:51:57Z  2025-03-06T07:51:57Z            4       NaN
# 635312  2025-03-06T07:51:14Z  2025-03-06T07:51:14Z           48       NaN
# 635313  2025-03-06T07:49:06Z  2025-03-06T07:49:06Z           91       NaN
#
#                                               textDisplay  \
# 0                                                    2023
# 1       Um afago delicioso na minha quarentena/isolame...
# 2                                                2020!!!!
# 3       "Deixei que tudo fosse...\nMas não vi nada"\nD...
# 4                                 Alguém em. 2018...massa
# ...                                                   ...
# 635309                     WHO IS AFTER RCB UNBOX EVENT 🎉
# 635310                                              Rcb 🎉
# 635311                             Rcb fan unboxing event
# 635312                                          Rcb fan ❤
# 635313               RCB ki post dekhkar kon kon aaya he❤
#
#                                              textOriginal  ...  viewCount  \
# 0                                                    2023  ...      33434
# 1       Um afago delicioso na minha quarentena/isolame...  ...      33434
# 2                                                2020!!!!  ...      33434
# 3       "Deixei que tudo fosse...\nMas não vi nada"\nD...  ...      33434
# 4                                 Alguém em. 2018...massa  ...      33434
# ...                                                   ...  ...        ...
# 635309                     WHO IS AFTER RCB UNBOX EVENT 🎉  ...  176401613
# 635310                                              Rcb 🎉  ...  176401613
# 635311                             Rcb fan unboxing event  ...  176401613
# 635312                                          Rcb fan ❤  ...  176401613
# 635313               RCB ki post dekhkar kon kon aaya he❤  ...  176401613
#
#        likeCount_y commentCount favoriteCount  privacyStatus  madeForKids  \
# 0            375.0           12             0         public        False
# 1            375.0           12             0         public        False
# 2            375.0           12             0         public        False
# 3            375.0           12             0         public        False
# 4            375.0           12             0         public        False
# ...            ...          ...           ...            ...          ...
# 635309   1264101.0        12431             0         public        False
# 635310   1264101.0        12431             0         public        False
# 635311   1264101.0        12431             0         public        False
# 635312   1264101.0        12431             0         public        False
# 635313   1264101.0        12431             0         public        False
#
#         selfDeclaredMadeForKids  uploadStatus embeddable  license
# 0                           NaN     processed       True  youtube
# 1                           NaN     processed       True  youtube
# 2                           NaN     processed       True  youtube
# 3                           NaN     processed       True  youtube
# 4                           NaN     processed       True  youtube
# ...                         ...           ...        ...      ...
# 635309                      NaN     processed       True  youtube
# 635310                      NaN     processed       True  youtube
# 635311                      NaN     processed       True  youtube
# 635312                      NaN     processed       True  youtube
# 635313                      NaN     processed       True  youtube
#
# [635314 rows x 41 columns]
