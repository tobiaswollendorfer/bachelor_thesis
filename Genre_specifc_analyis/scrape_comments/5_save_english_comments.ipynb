# %%
import pandas as pd

# %%
data = pd.read_csv("comments/final_dataset.csv")

# %%
data.shape
# Out:
# (620736, 160)

# %%
data['lang'] = data['lang'].astype(str).str.lower()
eng = data[data['lang'].str.startswith('en', na=False)].copy()
eng.to_csv('../data/final_dataset_english_only.csv')

# %%
eng
# Out:
#                          commentId           authorChannelId  \
# 10      UgxrR4wFxfCwvp2YUwZ4AaABAg  UC5jUy6FXCr82JYzq96-6_Jw
# 14      Ugw-qH8WQZqma_AugoN4AaABAg  UCPj69nCAxIJCqD0gKRjGGhA
# 15      UgywUe9rW4J6ynYErt54AaABAg  UCImqCrcNrl7S1NvrmleWDsg
# 17      UgzgxTaLTsQN9OPizbR4AaABAg  UC4YwlR3gBH0m8pvcDIOspaA
# 18      UgxoGDPYm0L0XFpNoUJ4AaABAg  UC4i1M5RayNtzd5f6Wuyr5sQ
# ...                            ...                       ...
# 620720  Ugz80rAR40R7fArC2LB4AaABAg  UCZgRHU_4W33ZqFEA0OHHrDg
# 620722  UgyUlxnQHfHfRV6bOPh4AaABAg  UC4KASbkO9VlSgKj_NHEWSWA
# 620726  UgzcPurv2BITJdR9_NZ4AaABAg  UCaBoXl1-gCTzfR73hvYq_IA
# 620731  UgzFGi4YnG2pIyT--ph4AaABAg  UCyNzYnJqU051zzDEhNbAfPg
# 620733  Ugx_ur0FsaxXWf5wLJJ4AaABAg  UC-X8KLDGa75PALKDJPVauyQ
#
#                    authorDisplayName  \
# 10           @a.m_0056skycloud-xf5ec
# 14      @angelinamidbjerlundholm3058
# 15                      @thesnesgeek
# 17            @fingerstylemelody8139
# 18                    @sarariley8696
# ...
